# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('train.csv',index_col='ID_code')
df.head()
# Out:
#          target    var_0   var_1   ...     var_197  var_198  var_199
# ID_code                            ...
# train_0       0   8.9255 -6.7863   ...      8.5635  12.7803  -1.0914
# train_1       0  11.5006 -4.1473   ...      8.7889  18.3560   1.9518
# train_2       0   8.6093 -2.7457   ...      8.2675  14.7222   0.3965
# train_3       0  11.0604 -2.1518   ...     10.2922  17.9697  -8.9996
# train_4       0   9.8369 -1.4834   ...      9.5031  17.9974  -8.8104
#
# [5 rows x 201 columns]

# %%
trues = df.loc[df['target']==1]
falses = df.loc[df['target']!=1].sample(frac=1)[:len(trues)]
data = pd.concat([trues,falses],ignore_index=True).sample(frac=1)
data.head()
# Out:
#        target    var_0   var_1   ...     var_197  var_198  var_199
# 13054       1  14.0194  0.6446   ...     10.0033  13.9405  -6.5812
# 28764       0   8.4035  1.8422   ...      8.7751  18.9077  -0.3193
# 19206       1   7.8355 -0.7182   ...      9.7844  15.2039  -7.1359
# 4748        1   9.4451 -9.3407   ...      9.3474  19.8831   4.5705
# 23203       0  13.3662 -6.6035   ...      8.9519  17.8182 -11.2863
#
# [5 rows x 201 columns]

# %%
y = df['target']
X = df.drop('target',axis=1)

test = pd.read_csv('test.csv',index_col='ID_code')

# %%
import lightgbm as lgb
from sklearn.model_selection import KFold

# %%
# K-fold corss validation with 10 fold
n_splits = 10
kf = KFold(n_splits=n_splits)

# model with LGB
import warnings
warnings.filterwarnings('ignore')

param = {'objective': 'binary', 'metric': 'auc', 'learning_rate': 0.0112, 'num_rounds': 7000, 'verbose': 1}
test_pred = np.zeros(len(test))
for fold, (train_indx, val_indx) in enumerate(kf.split(y)):
    print("Fold {}".format(fold+1))
    train_set = lgb.Dataset(X.iloc[train_indx], label=y.iloc[train_indx])
    val_set = lgb.Dataset(X.iloc[val_indx], label=y.iloc[val_indx])
    model = lgb.train(param, train_set, valid_sets=val_set, verbose_eval=500)
    test_pred += model.predict(test)/n_splits
# Out:
# Fold 1
# [500]	valid_0's auc: 0.849609
# [1000]	valid_0's auc: 0.870701
# [1500]	valid_0's auc: 0.880189
# [2000]	valid_0's auc: 0.88501
# [2500]	valid_0's auc: 0.888125
# [3000]	valid_0's auc: 0.889896
# [3500]	valid_0's auc: 0.890718
# [4000]	valid_0's auc: 0.891088
# [4500]	valid_0's auc: 0.891262
# [5000]	valid_0's auc: 0.891308
# [5500]	valid_0's auc: 0.891314
# [6000]	valid_0's auc: 0.891369
# [6500]	valid_0's auc: 0.891275
# [7000]	valid_0's auc: 0.891348
# Fold 2
# [500]	valid_0's auc: 0.853432
# [1000]	valid_0's auc: 0.874863
# [6500]	valid_0's auc: 0.897572
# [7000]	valid_0's auc: 0.897434
# Fold 7
# [500]	valid_0's auc: 0.852699
# [1000]	valid_0's auc: 0.876152
# [1500]	valid_0's auc: 0.885165
# [2000]	valid_0's auc: 0.889644
# [2500]	valid_0's auc: 0.892136
# [3000]	valid_0's auc: 0.893384
# [3500]	valid_0's auc: 0.893906
# [4000]	valid_0's auc: 0.894227
# [4500]	valid_0's auc: 0.894243
# [5000]	valid_0's auc: 0.894064
# [5500]	valid_0's auc: 0.893928
# [6000]	valid_0's auc: 0.893752
# [6500]	valid_0's auc: 0.893641
# [7000]	valid_0's auc: 0.893453
# Fold 8
# [500]	valid_0's auc: 0.854678
# [1000]	valid_0's auc: 0.875714
# [1500]	valid_0's auc: 0.884792
# [2000]	valid_0's auc: 0.889536
# [2500]	valid_0's auc: 0.892061
# [3000]	valid_0's auc: 0.893544
# [3500]	valid_0's auc: 0.894105
# [4000]	valid_0's auc: 0.894186
# [4500]	valid_0's auc: 0.894337
# [5000]	valid_0's auc: 0.8942
# [5500]	valid_0's auc: 0.894094
# [6000]	valid_0's auc: 0.894042
# [6500]	valid_0's auc: 0.893976
# [7000]	valid_0's auc: 0.893926
# Fold 9
# [500]	valid_0's auc: 0.861237
# [1000]	valid_0's auc: 0.88209
# [1500]	valid_0's auc: 0.890777
# [2000]	valid_0's auc: 0.895395
# [2500]	valid_0's auc: 0.897513
# [3000]	valid_0's auc: 0.898901
# [3500]	valid_0's auc: 0.899365
# [4000]	valid_0's auc: 0.899695
# [4500]	valid_0's auc: 0.899863
# [5000]	valid_0's auc: 0.899804
# [5500]	valid_0's auc: 0.899865
# [6000]	valid_0's auc: 0.899736
# [6500]	valid_0's auc: 0.899692
# [7000]	valid_0's auc: 0.899504
# Fold 10
# [500]	valid_0's auc: 0.858519
# [1000]	valid_0's auc: 0.878959
# [1500]	valid_0's auc: 0.887506
# [2000]	valid_0's auc: 0.892019
# [2500]	valid_0's auc: 0.8945
# [3000]	valid_0's auc: 0.896192
# [3500]	valid_0's auc: 0.896826
# [4000]	valid_0's auc: 0.897098
# [4500]	valid_0's auc: 0.897287
# [5000]	valid_0's auc: 0.897352
# [5500]	valid_0's auc: 0.897409
# [6000]	valid_0's auc: 0.897508
# [6500]	valid_0's auc: 0.897406
# [7000]	valid_0's auc: 0.897481

# %%
test_pred
# Out:
# array([0.06730757, 0.23808998, 0.20322732, ..., 0.00369577, 0.08717211,
#        0.05386662])

# %%
submission = pd.read_csv('../input/sample_submission.csv')
sub = pd.DataFrame(test_pred,columns=['target'])
submission.update(sub)

# %%
submission.to_csv('lightgbm.csv',index=False)
